# %%
# %matplotlib inline
import skrf as rf
rf.stylely()
# Out:
# C:\Users\ncoburn\AppData\Local\Continuum\anaconda3\lib\site-packages\skrf\plotting.py:1411: UserWarning: Style includes a parameter, 'interactive', that is not related to style.  Ignoring
#   mpl.style.use(os.path.join(pwd, style_file))

# %%
from skrf import Network

ring_slot = Network('s11_sorex_2020611.s1p')
ring_slot.plot_s_smith()

# %%
ring_slot.plot_s_smith(draw_labels=True)

# %%
ring_slot.plot_s_smith(chart_type='y')

# %%
ring_slot.plot_s_complex()

from matplotlib import pyplot as plt
plt.axis('equal') # otherwise circles wont be circles
# Out:
# (0.00071406644, 0.0074228193, -0.0547555094, 0.0633697174)

# %%
ring_slot.plot_s_db()

# %%
from skrf.data import ring_slot_meas
ring_slot.plot_s_db(m=0,n=0, label='Theory')
ring_slot_meas.plot_s_db(m=0,n=0, label='Measurement')

# %%
ring_slot.plot_s_deg()

# %%
ring_slot.plot_s_deg_unwrap()

# %%
gd = abs(ring_slot.s11.group_delay) *1e9 # in ns

ring_slot.plot(gd)
plt.ylabel('Group Delay (ns)')
plt.title('Group Delay of Ring Slot S11')
# Out:
# Text(0.5, 1.0, 'Group Delay of Ring Slot S11')

# %%
ring_slot.plot_z_im()

# %%
ring_slot.plot_z_db()
ring_slot.plot_z_mag()
#ring_slot.plot_z_im()
#ring_slot.plot_z_re()

# %%
ring_slot.plot_z_db()

# %%
ring_slot.plot_y_im()

# %%
ring_slot.plot_y_re()

# %%
ring_slot.s11.plot_s_smith()

# %%
ring_slot.plot_s_smith()

# %%
import junix; junix.export_images(filepath=".s1p_skrf.ipynb") #save all figures in .png format to filepath
